# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python drive/MyDrive/Code/VideoAnomalyPipeline.py --mode all --model "CNN-LSTM" --dataset crime-ucf --epochs 5
# Out:
# [INFO] Missing dependencies ['boto3', 'python-docx']. Installing...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 20.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 143.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.2/90.2 kB 11.9 MB/s eta 0:00:00
# ...
# [INFO] Path verification in progress...
# [SUCCESS] DATASET_PATH verified: /content/drive/MyDrive/VideoDataset
# [SUCCESS] LOGS_PATH verified: /content/drive/MyDrive/Code/logs
# [SUCCESS] RESULTS_PATH verified: /content/drive/MyDrive/Code/results
# [INFO] Session logging started (appending to /content/drive/MyDrive/Code/logs/pipeline_execution.log)
#
# ...
# RUNNING ALL-IN-ONE VIDEO PIPELINE: CNN-LSTM on crime-ucf
#   trainingseed=1  inferenceseed=1
# ...
#
# [STEP 1/5] Environment Check
#
# ...
# INITIAL CONFIGURATION & ENVIRONMENT CHECK
# ...
#
# [1/4] Libraries and Dependencies:
# ...

# %%
# !python drive/MyDrive/Code/VideoAnomalyPipeline.py --mode all --model "3D CNN" --dataset crime-ucf --epochs 5
# Out:
# [INFO] Path verification in progress...
# [SUCCESS] DATASET_PATH verified: /content/drive/MyDrive/VideoDataset
# [SUCCESS] LOGS_PATH verified: /content/drive/MyDrive/Code/logs
# [SUCCESS] RESULTS_PATH verified: /content/drive/MyDrive/Code/results
# [INFO] Session logging started (appending to /content/drive/MyDrive/Code/logs/pipeline_execution.log)
#
# ...
# RUNNING ALL-IN-ONE VIDEO PIPELINE: 3D CNN on crime-ucf
#   trainingseed=1  inferenceseed=1
# ...
#
# [STEP 1/5] Environment Check
#
# ...
# INITIAL CONFIGURATION & ENVIRONMENT CHECK
# ...
#
# [1/4] Libraries and Dependencies:
#   [OK] Pillow                 : v11.3.0
#   [OK] numpy                  : v2.0.2
#   [OK] matplotlib             : v3.10.0
#   [OK] seaborn                : v0.13.2
#   [OK] scipy                  : v1.16.3
#   [OK] scikit-learn           : v1.6.1
#   [OK] pandas                 : v2.2.2
#   [OK] boto3                  : v1.43.72
#   [OK] psutil                 : v5.9.5
#   [OK] python-docx            : v1.2.0
# ...

# %%
# !python drive/MyDrive/Code/VideoAnomalyPipeline.py --mode all --model "Video Transformer" --dataset crime-ucf --epochs 5
