# %%
# 2. Mount Google Drive (your dataset must be here)
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python drive/MyDrive/Code/ImageAnomalyPipeline.py --mode all --model EfficientNetB0 --epochs 5 --dataset yonsei_faces

# %%
# !python drive/MyDrive/Code/ImageAnomalyPipeline.py --mode all --model ResNet50 --epochs 5 --dataset yonsei_faces

# %%
# !python drive/MyDrive/Code/ImageAnomalyPipeline.py --mode all --model DenseNet121 --epochs 5 --dataset yonsei_faces
